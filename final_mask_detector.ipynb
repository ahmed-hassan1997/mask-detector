# %% [markdown]
# ## connect to google drive

# %% [markdown]
# ## connect to ahmedm97 account

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Get the runtime details**

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"

# %% [markdown]
# **Update the Repo list**

# %%
# !apt-get update
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done

# %% [markdown]
# **Show the current working directory**

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# **Unzip the darknet zip file to the /content folder**

# %%
# !unzip "/content/gdrive/MyDrive/detect_mask_project/mask_detector.zip"
# Out:
# Archive:  /content/gdrive/MyDrive/detect_mask_project/mask_detector.zip
# replace content/darknet/.circleci/config.yml? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# **Go inside the darknet folder of our runtime**

# %%
# %cd /content/content/darknet
# Out:
# /content/content/darknet

# %% [markdown]
# **Install dos2unix to convert dos files to unix encoding**

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dos2unix is already the newest version (7.3.4-3).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %% [markdown]
# **Convert all files in darknet folder to unix encoding**

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Streaming output truncated to the last 5000 lines.
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/99_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/69_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/101_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/60_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/66_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/123_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/36_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/72_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/58_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/42_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/36_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/102_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/92_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/43_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/107_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/107_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/82_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/116_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/39_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/90_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/51_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/49_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/110_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/119_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/115_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/36_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/60_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/61_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/49_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/59_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/112_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/86_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/108_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/39_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/46_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/101_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/83_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/123_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/65_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/80_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/65_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/117_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/93_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/88_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/87_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/118_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/63_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/55_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/82_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/52_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/70_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/59_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/120_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/104_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/85_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/77_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/56_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/41_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/64_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/46_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/55_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/47_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/49_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/96_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/99_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/120_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/48_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/103_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/90_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/66_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/32_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/126_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/61_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/122_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/55_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/44_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/67_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/84_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/126_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/114_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/60_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/96_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/94_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/92_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/79_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/86_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/113_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/87_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/40_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/49_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/116_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/51_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/50_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/126_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/43_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/46_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/58_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/33_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/73_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/122_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/79_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/84_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/68_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/91_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/101_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/32_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/47_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/113_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/112_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/86_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/46_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/39_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/115_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/81_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/95_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/101_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/39_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/68_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/40_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/78_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/74_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/97_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/93_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/87_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/48_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/80_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/47_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/56_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/82_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/57_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/82_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/100_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/68_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/78_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/121_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/71_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/32_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/95_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/51_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/125_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/107_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/81_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/38_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/104_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/37_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/103_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/57_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/119_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/46_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/109_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/106_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/90_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/40_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/96_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/114_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/58_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/50_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/77_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/85_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/74_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/114_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/68_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/65_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/115_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/53_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/109_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/86_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/95_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/45_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/66_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/115_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/62_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/119_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/70_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/94_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/82_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/101_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/90_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/70_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/35_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/78_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/65_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/91_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/115_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/68_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/55_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/107_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/65_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/37_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/50_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/104_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/125_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/90_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/96_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/90_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/69_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/105_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/44_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/124_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/76_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/34_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/74_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/98_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/108_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/34_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/123_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/79_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/86_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/98_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/121_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/97_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/116_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/38_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/63_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/46_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/72_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/78_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/91_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/59_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/62_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/85_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/121_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/112_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/95_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/112_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/49_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/43_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/81_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/116_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/95_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/104_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/108_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/116_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/77_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/75_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/69_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/118_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/76_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/60_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/122_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/32_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/61_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/83_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/79_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/41_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/64_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/46_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/106_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/119_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/88_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/105_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/85_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/47_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/91_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/82_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/117_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/63_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/52_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/88_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/102_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/55_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/87_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/58_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/78_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/99_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/106_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/57_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/93_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/62_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/110_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/71_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/99_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/75_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/58_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/105_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/100_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/32_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/50_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/74_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/64_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/87_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/114_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/117_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/54_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/45_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/53_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/92_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/76_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/64_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/67_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/122_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/72_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/83_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/81_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/125_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/86_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/72_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/41_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/99_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/91_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/75_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/67_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/69_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/40_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/58_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/34_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/42_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/85_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/101_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/43_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/79_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/94_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/107_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/122_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/64_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/111_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/42_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/123_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/83_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/37_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/124_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/124_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/116_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/77_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/32_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/97_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/93_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/105_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/118_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/126_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/123_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/39_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/61_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/38_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/58_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/111_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/61_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/101_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/71_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/32_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/94_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/104_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/117_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/54_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/48_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/35_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/109_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/125_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/42_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/80_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/99_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/101_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/66_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/41_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/89_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/37_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/65_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/84_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/44_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/50_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/74_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/96_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/43_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/94_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/33_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/74_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/113_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/93_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/68_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/77_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/88_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/113_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/34_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/115_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/70_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/75_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/70_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/52_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/33_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/99_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/98_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/92_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/87_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/35_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/86_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/112_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/97_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/82_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/70_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/125_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/67_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/53_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/68_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/62_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/94_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/121_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/45_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/72_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/100_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/80_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/122_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/107_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/63_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/84_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/50_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/83_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/124_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./build/darknet/x64/data/labels/71_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# ...
# dos2unix: Skipping binary file ./data/labels/111_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/125_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/51_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/71_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/121_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/88_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/100_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/62_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/36_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/100_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/117_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/123_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/49_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/55_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/109_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/124_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/118_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/85_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/62_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/46_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/64_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/64_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/78_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/117_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/43_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/33_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/93_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/126_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/89_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/123_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/35_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/59_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/106_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/126_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/85_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/102_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/84_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/120_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/53_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/58_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/39_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/73_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/100_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/80_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/61_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/94_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/81_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/67_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/75_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/59_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/91_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/35_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/110_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/120_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/110_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/98_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/100_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/110_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/120_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/89_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/40_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/111_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/97_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/103_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/111_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/116_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/54_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/92_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/47_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/107_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/42_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/83_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/88_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/84_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/105_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/76_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/57_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/63_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/91_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/37_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/103_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/52_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/121_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/78_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/80_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/122_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/37_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/120_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/80_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/115_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/54_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/74_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/76_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/70_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/51_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/98_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/72_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/80_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/89_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/45_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/110_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/124_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/41_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/102_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/85_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/52_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/118_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/42_7.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/121_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/35_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/92_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/117_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/97_1.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/111_0.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/123_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/75_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/114_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/115_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/45_5.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/38_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/118_4.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/87_3.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/72_6.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/105_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/52_2.png
# dos2unix: Binary symbol 0x1A found at line 2
# dos2unix: Skipping binary file ./data/labels/70_1.png
# dos2unix: converting file ./data/voc.names to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./data/scream.jpg
# dos2unix: converting file ./data/9k.tree to Unix format...
# dos2unix: converting file ./data/coco9k.map to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./data/giraffe.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./data/horses.jpg
# dos2unix: converting file ./darknet_images.py to Unix format...
# dos2unix: converting file ./build.sh to Unix format...
# dos2unix: converting file ./scripts/voc_label.py to Unix format...
# dos2unix: converting file ./scripts/voc_eval.py to Unix format...
# dos2unix: converting file ./scripts/get_openimages_dataset.py to Unix format...
# dos2unix: converting file ./scripts/windows/win_install_cygwin.cmd to Unix format...
# dos2unix: converting file ./scripts/windows/otb_get_labels.sh to Unix format...
# dos2unix: converting file ./scripts/windows/windows_imagenet_train.sh to Unix format...
# dos2unix: converting file ./scripts/windows/windows_imagenet_label.sh to Unix format...
# dos2unix: converting file ./scripts/windows/win_cifar.cmd to Unix format...
# dos2unix: converting file ./scripts/windows/win_get_imagenet_train_48hours.cmd to Unix format...
# dos2unix: converting file ./scripts/windows/win_get_imagenet_valid.cmd to Unix format...
# dos2unix: converting file ./scripts/windows/win_get_otb_datasets.cmd to Unix format...
# dos2unix: converting file ./scripts/log_parser/test_new.svg to Unix format...
# dos2unix: converting file ./scripts/log_parser/run_log_parser_windows.cmd to Unix format...
# dos2unix: converting file ./scripts/log_parser/log_parser.py to Unix format...
# dos2unix: converting file ./scripts/log_parser/test.log to Unix format...
# dos2unix: converting file ./scripts/log_parser/readme.md to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./scripts/log_parser/plot.jpg
# dos2unix: converting file ./scripts/log_parser/test_new.log to Unix format...
# dos2unix: converting file ./scripts/setup.ps1 to Unix format...
# dos2unix: converting file ./scripts/testdev2017.txt to Unix format...
# dos2unix: converting file ./scripts/voc_eval_py3.py to Unix format...
# dos2unix: converting file ./scripts/get_imagenet_train.sh to Unix format...
# dos2unix: converting file ./scripts/get_coco_dataset.sh to Unix format...
# dos2unix: converting file ./scripts/reval_voc_py3.py to Unix format...
# dos2unix: converting file ./scripts/kitti2yolo.py to Unix format...
# dos2unix: converting file ./scripts/install_OpenCV4.sh to Unix format...
# dos2unix: converting file ./scripts/reval_voc.py to Unix format...
# dos2unix: converting file ./scripts/gen_anchors.py to Unix format...
# dos2unix: converting file ./scripts/voc_label_difficult.py to Unix format...
# dos2unix: converting file ./scripts/gen_tactic.sh to Unix format...
# dos2unix: converting file ./scripts/README.md to Unix format...
# dos2unix: converting file ./scripts/imagenet_label.sh to Unix format...
# dos2unix: converting file ./scripts/setup.sh to Unix format...
# dos2unix: converting file ./scripts/dice_label.sh to Unix format...
# dos2unix: converting file ./scripts/kmeansiou.c to Unix format...
# dos2unix: converting file ./net_cam_v3.sh to Unix format...
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./yolov4.weights
# dos2unix: converting file ./darknet_video.py to Unix format...
# dos2unix: converting file ./Makefile to Unix format...

# %% [markdown]
# **Give executable permission for files in /content/darknet**

# %%
# !chmod +x /content/content/darknet

# %% [markdown]
# **make sure of the current directory**

# %%
# %pwd
# Out:
# '/content/content/darknet'

# %% [markdown]
# **Compile the darknet framework**

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ./src/image_opencv.cpp:1130:10: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#           if (iteration_old != 0){
#           ^~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1424:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1400:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1404:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1408:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1411:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:580:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#
# ./src/http_stream.cpp:73:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:507:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:845:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ./src/http_stream.cpp:853:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#                           ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:873:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#                          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:908:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#          ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2038:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2037:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1040:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#      while (c = *str++)
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:224:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:276:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:276:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:276:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:286:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:307:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:322:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:328:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1337:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                           ~^
#                                                           %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                   ~^
#                                                                   %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                           ~^
#                                                                           %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                    ~^
#                                                                    %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                            ~^
#                                                                            %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                                    ~^
#                                                                                    %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:780:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:780:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:202:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#      fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#                                                                                                    ~~^
#                                                                                                    %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:243:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#                      float max_truth = 0;
#                            ^~~~~~~~~
# ./src/softmax_layer.c:420:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#              printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#                                                                       ~^
#                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1294:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1090:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:615:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1652:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:418:29: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#          classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#          ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:0:
# /usr/include/stdlib.h:541:14: note: in a call to allocation function ‘calloc’ declared here
#  extern void *calloc (size_t __nmemb, size_t __size)
#               ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:477:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:570:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:691:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:689:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1322:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1321:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1856:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:204:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1287:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1287:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:16: warning: unused variable ‘prediction’ [-Wunused-variable]
#          float *prediction = network_predict(net, X);
#                 ^~~~~~~~~~
# ./src/demo.c:98:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:59:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:58:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:66:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:73:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:103:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:112:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:390:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:71:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# ./src/convolutional_kernels.cu: In function ‘void backward_convolutional_layer_gpu(convolutional_layer, network_state)’:
# ./src/convolutional_kernels.cu:845:40: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (*state.net.max_output16_size < l.nweights) {
#                  ~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:364:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %% [markdown]
# **Test the darkent framework with sample object detection**
#
# > Indented block

# %%
# !pwd
# Out:
# /content/content/darknet

# %% [markdown]
# ## test with simple image

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    8 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    9 route  8 2 	                           ->  304 x 304 x 128
#   10 conv     64       1 x 1/ 1    304 x 304 x 128 ->  304 x 304 x  64 1.514 BF
#   11 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#   12 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   13 route  11 		                           ->  152 x 152 x 128
#   14 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   15 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   16 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   19 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   22 route  21 12 	                           ->  152 x 152 x 128
#   23 conv    128       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x 128 0.757 BF
#   24 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 route  24 		                           ->   76 x  76 x 256
#   27 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   29 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   32 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   35 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   38 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   41 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   44 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   47 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   50 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   53 route  52 25 	                           ->   76 x  76 x 256
#   54 conv    256       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 256 0.757 BF
#   55 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 route  55 		                           ->   38 x  38 x 512
#   58 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   60 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   63 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   66 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   69 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   72 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   75 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   78 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   81 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   84 route  83 56 	                           ->   38 x  38 x 512
#   85 conv    512       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 512 0.757 BF
#   86 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   87 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   88 route  86 		                           ->   19 x  19 x1024
#   89 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   90 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   91 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   94 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   97 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  100 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  103 route  102 87 	                           ->   19 x  19 x1024
#  104 conv   1024       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x1024 0.757 BF
#  105 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  106 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  107 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  108 max                5x 5/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.005 BF
#  109 route  107 		                           ->   19 x  19 x 512
#  110 max                9x 9/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.015 BF
#  111 route  107 		                           ->   19 x  19 x 512
#  112 max               13x13/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.031 BF
#  113 route  112 110 108 107 	                   ->   19 x  19 x2048
#  114 conv    512       1 x 1/ 1     19 x  19 x2048 ->   19 x  19 x 512 0.757 BF
#  115 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  116 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  117 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#  118 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#  119 route  85 		                           ->   38 x  38 x 512
#  120 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  121 route  120 118 	                           ->   38 x  38 x 512
#  122 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  123 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  124 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  125 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  126 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  127 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#  128 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#  129 route  54 		                           ->   76 x  76 x 256
#  130 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  131 route  130 128 	                           ->   76 x  76 x 256
#  132 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  133 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  134 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  135 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  136 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  137 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  138 conv    255       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 255 0.754 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   76 x  76 x 128
#  141 conv    256       3 x 3/ 2     76 x  76 x 128 ->   38 x  38 x 256 0.852 BF
#  142 route  141 126 	                           ->   38 x  38 x 512
#  143 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  144 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  145 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  146 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  147 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  148 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  149 conv    255       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 255 0.377 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   38 x  38 x 256
#  152 conv    512       3 x 3/ 2     38 x  38 x 256 ->   19 x  19 x 512 0.852 BF
#  153 route  152 116 	                           ->   19 x  19 x1024
#  154 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  155 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  156 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  157 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  158 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  159 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  160 conv    255       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 255 0.189 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, cls_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 128.459
# avg_outputs = 1068395
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from yolov4.weights...
#  seen 64, trained: 32032 K-images (500 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
#  Detection layer: 139 - type = 27
#  Detection layer: 150 - type = 27
#  Detection layer: 161 - type = 27
# data/person.jpg: Predicted in 78.931000 milli-seconds.
# dog: 99%
# person: 100%
# horse: 98%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:4529): Gtk-WARNING **: 16:19:03.754: cannot open display:

# %% [markdown]
# **Remove the default backup folder of darknet in runtime**

# %%
# !rm /content/content/darknet/backup -r

# %% [markdown]
# **Create a symbolic link from runtime darknet folder to google drive backup folder with the name 'backup'**

# %% [markdown]
# 1- to create sympolic link
#
# * first inside darknet create folder(cov_weights) and inside it create (backup) folder
#
# * then link darknet to it

# %%
# !ln -s "/content/gdrive/My Drive/cov_weights/backup" "/content/content/darknet"

# %% [markdown]
# **check the directory**

# %%
# %pwd
# Out:
# '/content/content/darknet'

# %% [markdown]
# ## if you want to change epochs just change in max_steps in yolo_cfg

# %% [markdown]
# **Proceed with fresh Training Using the cov dataset**

# %%
##                                          configuration   weights
# !./darknet detector train mask_detection/mask.data cov_yolov4.cfg yolov4.conv.137 -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.220662, GIOU: 0.220662), Class: 0.464423, Obj: 0.199298, No Obj: 0.238957, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 225.955139, iou_loss = 0.067719, total_loss = 226.022858
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.428212, GIOU: 0.357566), Class: 0.468524, Obj: 0.408480, No Obj: 0.346453, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 115.139359, iou_loss = 0.136307, total_loss = 115.275665
#  total_bbox = 51460, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.130558, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 283.819611, iou_loss = 0.000000, total_loss = 283.819611
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.242648, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 233.123169, iou_loss = 0.000000, total_loss = 233.123169
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.394865, GIOU: 0.394865), Class: 0.447232, Obj: 0.372552, No Obj: 0.349477, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 117.502831, iou_loss = 0.033005, total_loss = 117.535835
#  total_bbox = 51462, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.134401, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 300.796783, iou_loss = 0.000000, total_loss = 300.796783
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.243155, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 232.265930, iou_loss = 0.000000, total_loss = 232.265930
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.783101, GIOU: 0.770345), Class: 0.563364, Obj: 0.323119, No Obj: 0.353047, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 118.670944, iou_loss = 0.031525, total_loss = 118.702469
#  total_bbox = 51463, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.133150, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 290.510712, iou_loss = 0.000000, total_loss = 290.510712
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.246858, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 239.006714, iou_loss = 0.000000, total_loss = 239.006714
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.498991, GIOU: 0.498991), Class: 0.529241, Obj: 0.387042, No Obj: 0.353776, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 120.004463, iou_loss = 0.055229, total_loss = 120.059692
#  total_bbox = 51465, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.137673, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 316.241699, iou_loss = 0.000000, total_loss = 316.241699
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.247963, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 241.335571, iou_loss = 0.000000, total_loss = 241.335571
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.411942, GIOU: 0.389189), Class: 0.602468, Obj: 0.396201, No Obj: 0.350157, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 116.844917, iou_loss = 0.029007, total_loss = 116.873924
#  total_bbox = 51467, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.130576, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 282.168335, iou_loss = 0.000000, total_loss = 282.168335
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.237655, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 222.294754, iou_loss = 0.000000, total_loss = 222.294754
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.310079, GIOU: 0.310080), Class: 0.487366, Obj: 0.453138, No Obj: 0.345564, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 113.390236, iou_loss = 0.038452, total_loss = 113.428688
#  total_bbox = 51469, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.131019, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 285.045837, iou_loss = 0.000000, total_loss = 285.045837
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.241676, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 230.328094, iou_loss = 0.000000, total_loss = 230.328094
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.307360, GIOU: 0.307360), Class: 0.418237, Obj: 0.402255, No Obj: 0.349478, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 117.528244, iou_loss = 0.038445, total_loss = 117.566689
#  total_bbox = 51471, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.134688, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 298.138428, iou_loss = 0.000000, total_loss = 298.138428
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.249279, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 244.955475, iou_loss = 0.000000, total_loss = 244.955475
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.268038, GIOU: 0.190230), Class: 0.519154, Obj: 0.370842, No Obj: 0.350528, .5R: 0.200000, .75R: 0.000000, count: 5, class_loss = 119.752525, iou_loss = 0.103653, total_loss = 119.856178
#  total_bbox = 51476, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.129642, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 279.389008, iou_loss = 0.000000, total_loss = 279.389008
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.239850, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 227.911575, iou_loss = 0.000000, total_loss = 227.911575
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.427420, GIOU: 0.399898), Class: 0.584417, Obj: 0.382108, No Obj: 0.345394, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 114.441772, iou_loss = 0.030693, total_loss = 114.472466
#  total_bbox = 51478, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.129652, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 276.613831, iou_loss = 0.000000, total_loss = 276.613831
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.244463, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 233.175415, iou_loss = 0.000000, total_loss = 233.175415
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.418467, GIOU: 0.393679), Class: 0.517792, Obj: 0.437609, No Obj: 0.361557, .5R: 0.285714, .75R: 0.000000, count: 7, class_loss = 127.937057, iou_loss = 0.260406, total_loss = 128.197464
#  total_bbox = 51485, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.129821, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 276.818237, iou_loss = 0.000000, total_loss = 276.818237
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.250548, GIOU: 0.145756), Class: 0.563411, Obj: 0.271500, No Obj: 0.245262, .5R: 0.000000, .75R: 0.000000, count: 4, class_loss = 238.730194, iou_loss = 0.522232, total_loss = 239.252426
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.378814, GIOU: 0.346373), Class: 0.470888, Obj: 0.441823, No Obj: 0.355213, .5R: 0.142857, .75R: 0.000000, count: 7, class_loss = 123.983879, iou_loss = 0.414825, total_loss = 124.398705
#  total_bbox = 51496, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.128826, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 272.872620, iou_loss = 0.000000, total_loss = 272.872620
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.420072, GIOU: 0.420072), Class: 0.530864, Obj: 0.343341, No Obj: 0.241662, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 229.519333, iou_loss = 0.245483, total_loss = 229.764816
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.371145, GIOU: 0.289320), Class: 0.527713, Obj: 0.400161, No Obj: 0.353055, .5R: 0.300000, .75R: 0.300000, count: 10, class_loss = 125.033440, iou_loss = 0.505547, total_loss = 125.538986
#  total_bbox = 51507, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.127593, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 270.191528, iou_loss = 0.000000, total_loss = 270.191528
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.242934, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 231.911285, iou_loss = 0.000000, total_loss = 231.911285
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.324209, GIOU: 0.300635), Class: 0.498415, Obj: 0.327567, No Obj: 0.352379, .5R: 0.181818, .75R: 0.000000, count: 11, class_loss = 126.463493, iou_loss = 0.371407, total_loss = 126.834900
#  total_bbox = 51518, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.126281, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 259.636230, iou_loss = 0.000000, total_loss = 259.636230
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.199684, GIOU: 0.127111), Class: 0.428059, Obj: 0.297821, No Obj: 0.240920, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 229.616470, iou_loss = 0.220367, total_loss = 229.836838
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.386237, GIOU: 0.336198), Class: 0.484184, Obj: 0.364479, No Obj: 0.356070, .5R: 0.285714, .75R: 0.142857, count: 7, class_loss = 126.020760, iou_loss = 0.661484, total_loss = 126.682243
#  total_bbox = 51528, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.134774, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 299.051331, iou_loss = 0.000000, total_loss = 299.051331
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.356839, GIOU: 0.284721), Class: 0.575066, Obj: 0.287299, No Obj: 0.249016, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 243.653214, iou_loss = 0.746078, total_loss = 244.399292
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.299558, GIOU: 0.163201), Class: 0.507205, Obj: 0.420737, No Obj: 0.356131, .5R: 0.000000, .75R: 0.000000, count: 8, class_loss = 124.530441, iou_loss = 0.212746, total_loss = 124.743187
#  total_bbox = 51539, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.129328, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 274.243256, iou_loss = 0.000000, total_loss = 274.243256
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.202889, GIOU: 0.144198), Class: 0.592028, Obj: 0.260664, No Obj: 0.238459, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 225.330505, iou_loss = 0.208572, total_loss = 225.539078
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.378990, GIOU: 0.293561), Class: 0.536637, Obj: 0.398642, No Obj: 0.350150, .5R: 0.375000, .75R: 0.000000, count: 8, class_loss = 122.134651, iou_loss = 0.273041, total_loss = 122.407692
#  total_bbox = 51550, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.131375, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 282.157745, iou_loss = 0.000000, total_loss = 282.157745
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.316457, GIOU: 0.270563), Class: 0.406605, Obj: 0.370864, No Obj: 0.244325, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 235.881699, iou_loss = 0.413422, total_loss = 236.295120
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.484993, GIOU: 0.441342), Class: 0.502838, Obj: 0.418225, No Obj: 0.353675, .5R: 0.333333, .75R: 0.111111, count: 9, class_loss = 124.401871, iou_loss = 0.656052, total_loss = 125.057922
#  total_bbox = 51562, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.132877, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 289.473663, iou_loss = 0.000000, total_loss = 289.473663
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.116512, GIOU: 0.116512), Class: 0.585367, Obj: 0.315243, No Obj: 0.244363, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 234.337387, iou_loss = 0.038544, total_loss = 234.375931
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.355223, GIOU: 0.310812), Class: 0.551700, Obj: 0.395034, No Obj: 0.349524, .5R: 0.222222, .75R: 0.000000, count: 9, class_loss = 121.746742, iou_loss = 0.193970, total_loss = 121.940712
#  total_bbox = 51573, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.136961, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 307.338562, iou_loss = 0.000000, total_loss = 307.338562
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.203308, GIOU: 0.203308), Class: 0.452317, Obj: 0.321186, No Obj: 0.250893, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 247.315170, iou_loss = 0.180450, total_loss = 247.495621
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.461127, GIOU: 0.405706), Class: 0.496326, Obj: 0.409219, No Obj: 0.354954, .5R: 0.500000, .75R: 0.000000, count: 10, class_loss = 126.165779, iou_loss = 0.657440, total_loss = 126.823219
#  total_bbox = 51586, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.134820, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 301.604156, iou_loss = 0.000000, total_loss = 301.604156
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.247320, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 240.501678, iou_loss = 0.000000, total_loss = 240.501678
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.427114, GIOU: 0.349834), Class: 0.493273, Obj: 0.422238, No Obj: 0.352983, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 118.951218, iou_loss = 0.037178, total_loss = 118.988396
#  total_bbox = 51588, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.133779, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 296.015961, iou_loss = 0.000000, total_loss = 296.015961
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.247009, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 240.126144, iou_loss = 0.000000, total_loss = 240.126144
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.354490, GIOU: 0.312022), Class: 0.467722, Obj: 0.374831, No Obj: 0.351945, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 118.006012, iou_loss = 0.018524, total_loss = 118.024536
#  total_bbox = 51590, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.133487, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 295.242004, iou_loss = 0.000000, total_loss = 295.242004
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.244167, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 234.625580, iou_loss = 0.000000, total_loss = 234.625580
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.214183, GIOU: 0.214183), Class: 0.537748, Obj: 0.366999, No Obj: 0.352108, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 119.064247, iou_loss = 0.017250, total_loss = 119.081497
#  total_bbox = 51592, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.129934, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 278.478699, iou_loss = 0.000000, total_loss = 278.478699
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.243649, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 234.109497, iou_loss = 0.000000, total_loss = 234.109497
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.349419, GIOU: 0.244068), Class: 0.584482, Obj: 0.265609, No Obj: 0.349670, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 117.511330, iou_loss = 0.032402, total_loss = 117.543732
#  total_bbox = 51594, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.130017, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 278.530273, iou_loss = 0.000000, total_loss = 278.530273
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.241502, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 230.878632, iou_loss = 0.000000, total_loss = 230.878632
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.375883, GIOU: 0.340055), Class: 0.472710, Obj: 0.336078, No Obj: 0.347407, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 116.764809, iou_loss = 0.022919, total_loss = 116.787727
#  total_bbox = 51596, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.131777, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 287.403198, iou_loss = 0.000000, total_loss = 287.403198
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.241054, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 228.784927, iou_loss = 0.000000, total_loss = 228.784927
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.453119, GIOU: 0.311994), Class: 0.575460, Obj: 0.320119, No Obj: 0.350035, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 117.557564, iou_loss = 0.007698, total_loss = 117.565262
#  total_bbox = 51597, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.130211, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 279.865692, iou_loss = 0.000000, total_loss = 279.865692
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.244071, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 234.585693, iou_loss = 0.000000, total_loss = 234.585693
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.384553, GIOU: 0.381757), Class: 0.524647, Obj: 0.395596, No Obj: 0.350513, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 118.017944, iou_loss = 0.029945, total_loss = 118.047890
#  total_bbox = 51599, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.134882, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 302.939423, iou_loss = 0.000000, total_loss = 302.939423
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.244962, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 236.367218, iou_loss = 0.000000, total_loss = 236.367218
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.378740, GIOU: 0.292808), Class: 0.448366, Obj: 0.460122, No Obj: 0.348210, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 116.084610, iou_loss = 0.037338, total_loss = 116.121948
#  total_bbox = 51601, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.132576, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 291.607880, iou_loss = 0.000000, total_loss = 291.607880
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.244914, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 236.169540, iou_loss = 0.000000, total_loss = 236.169540
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.417380, GIOU: 0.401478), Class: 0.439752, Obj: 0.423902, No Obj: 0.352032, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 119.493362, iou_loss = 0.026733, total_loss = 119.520096
#  total_bbox = 51603, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.125560, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 259.648773, iou_loss = 0.000000, total_loss = 259.648773
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.238586, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 225.075821, iou_loss = 0.000000, total_loss = 225.075821
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.291135, GIOU: 0.291135), Class: 0.510882, Obj: 0.332724, No Obj: 0.344224, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 114.112358, iou_loss = 0.020927, total_loss = 114.133286
#  total_bbox = 51605, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.134618, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 298.913788, iou_loss = 0.000000, total_loss = 298.913788
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.247946, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 240.263214, iou_loss = 0.000000, total_loss = 240.263214
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.424389, GIOU: 0.424389), Class: 0.606364, Obj: 0.458141, No Obj: 0.354410, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 120.283287, iou_loss = 0.037720, total_loss = 120.321007
#  total_bbox = 51607, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.136228, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 303.972748, iou_loss = 0.000000, total_loss = 303.972748
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.223539, GIOU: 0.082331), Class: 0.495088, Obj: 0.276123, No Obj: 0.252674, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 251.196304, iou_loss = 0.224136, total_loss = 251.420441
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.377080, GIOU: 0.370408), Class: 0.556419, Obj: 0.372562, No Obj: 0.361594, .5R: 0.125000, .75R: 0.125000, count: 8, class_loss = 129.151001, iou_loss = 0.330566, total_loss = 129.481567
#  total_bbox = 51618, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.130513, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 279.015289, iou_loss = 0.000000, total_loss = 279.015289
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.204587, GIOU: 0.204587), Class: 0.507400, Obj: 0.309083, No Obj: 0.243695, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 233.907043, iou_loss = 0.197372, total_loss = 234.104416
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.483141, GIOU: 0.447917), Class: 0.552523, Obj: 0.381142, No Obj: 0.356472, .5R: 0.555556, .75R: 0.111111, count: 9, class_loss = 126.822166, iou_loss = 0.774315, total_loss = 127.596481
#  total_bbox = 51630, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.131960, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 286.854279, iou_loss = 0.000000, total_loss = 286.854279
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.230667, GIOU: 0.138404), Class: 0.366945, Obj: 0.248499, No Obj: 0.247585, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 241.579849, iou_loss = 0.176331, total_loss = 241.756180
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.387617, GIOU: 0.364603), Class: 0.528871, Obj: 0.417192, No Obj: 0.356716, .5R: 0.200000, .75R: 0.000000, count: 10, class_loss = 127.276176, iou_loss = 0.532875, total_loss = 127.809052
#  total_bbox = 51642, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.133021, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 291.013458, iou_loss = 0.000000, total_loss = 291.013458
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.407241, GIOU: 0.407241), Class: 0.492799, Obj: 0.305792, No Obj: 0.248122, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 241.651978, iou_loss = 0.230698, total_loss = 241.882675
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.347762, GIOU: 0.230133), Class: 0.484797, Obj: 0.343587, No Obj: 0.354401, .5R: 0.222222, .75R: 0.111111, count: 9, class_loss = 126.051399, iou_loss = 0.416451, total_loss = 126.467850
#  total_bbox = 51652, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.127834, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 268.328308, iou_loss = 0.000000, total_loss = 268.328308
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.144937, GIOU: 0.144936), Class: 0.602862, Obj: 0.249128, No Obj: 0.243024, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 232.327774, iou_loss = 0.029236, total_loss = 232.357010
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.349077, GIOU: 0.327009), Class: 0.498725, Obj: 0.361342, No Obj: 0.355389, .5R: 0.222222, .75R: 0.000000, count: 9, class_loss = 126.639160, iou_loss = 0.344284, total_loss = 126.983444
#  total_bbox = 51662, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.133002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 287.676819, iou_loss = 0.000000, total_loss = 287.676819
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.147763, GIOU: 0.147763), Class: 0.486779, Obj: 0.240290, No Obj: 0.248803, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 241.251068, iou_loss = 0.030457, total_loss = 241.281525
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.353060, GIOU: 0.283997), Class: 0.491477, Obj: 0.369971, No Obj: 0.358310, .5R: 0.250000, .75R: 0.083333, count: 12, class_loss = 130.795013, iou_loss = 0.645599, total_loss = 131.440613
#  total_bbox = 51675, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.133725, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 290.790802, iou_loss = 0.000000, total_loss = 290.790802
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.330126, GIOU: 0.247313), Class: 0.598789, Obj: 0.295531, No Obj: 0.251250, .5R: 0.250000, .75R: 0.000000, count: 4, class_loss = 249.418762, iou_loss = 2.184235, total_loss = 251.602997
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.368637, GIOU: 0.314813), Class: 0.563573, Obj: 0.385640, No Obj: 0.358913, .5R: 0.200000, .75R: 0.000000, count: 10, class_loss = 128.178238, iou_loss = 0.299042, total_loss = 128.477280
#  total_bbox = 51689, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.131897, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 286.183716, iou_loss = 0.000000, total_loss = 286.183716
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.201606, GIOU: 0.193388), Class: 0.609789, Obj: 0.288480, No Obj: 0.243364, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 233.683411, iou_loss = 0.133759, total_loss = 233.817169
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.293499, GIOU: 0.259518), Class: 0.511016, Obj: 0.403320, No Obj: 0.353509, .5R: 0.000000, .75R: 0.000000, count: 10, class_loss = 125.634193, iou_loss = 0.316689, total_loss = 125.950882
#  total_bbox = 51701, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.128456, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 268.284058, iou_loss = 0.000000, total_loss = 268.284058
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.280025, GIOU: 0.181909), Class: 0.442804, Obj: 0.274289, No Obj: 0.248119, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 240.573242, iou_loss = 0.083084, total_loss = 240.656326
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.477269, GIOU: 0.451271), Class: 0.516098, Obj: 0.401007, No Obj: 0.357257, .5R: 0.545455, .75R: 0.181818, count: 11, class_loss = 128.374146, iou_loss = 1.265274, total_loss = 129.639420
#  total_bbox = 51713, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.136087, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 302.210388, iou_loss = 0.000000, total_loss = 302.210388
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.147460, GIOU: 0.147460), Class: 0.354777, Obj: 0.340747, No Obj: 0.253471, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 251.205978, iou_loss = 0.063660, total_loss = 251.269638
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.354737, GIOU: 0.331675), Class: 0.479687, Obj: 0.368150, No Obj: 0.360973, .5R: 0.200000, .75R: 0.000000, count: 10, class_loss = 131.424713, iou_loss = 0.519089, total_loss = 131.943802
#  total_bbox = 51725, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.129034, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 272.060059, iou_loss = 0.000000, total_loss = 272.060059
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.242367, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 229.679657, iou_loss = 0.000000, total_loss = 229.679657
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.302901, GIOU: 0.299515), Class: 0.541946, Obj: 0.396873, No Obj: 0.351126, .5R: 0.200000, .75R: 0.000000, count: 10, class_loss = 124.209846, iou_loss = 0.179390, total_loss = 124.389236
#  total_bbox = 51735, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.131653, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 285.145416, iou_loss = 0.000000, total_loss = 285.145416
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.226128, GIOU: 0.226128), Class: 0.533103, Obj: 0.287161, No Obj: 0.246986, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 239.538391, iou_loss = 0.071503, total_loss = 239.609894
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.441020, GIOU: 0.383182), Class: 0.517248, Obj: 0.369445, No Obj: 0.356696, .5R: 0.375000, .75R: 0.125000, count: 8, class_loss = 127.108002, iou_loss = 0.630264, total_loss = 127.738266
#  total_bbox = 51744, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.128804, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 272.846771, iou_loss = 0.000000, total_loss = 272.846771
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.240131, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 225.468735, iou_loss = 0.000000, total_loss = 225.468735
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.282480, GIOU: 0.240245), Class: 0.542911, Obj: 0.331622, No Obj: 0.348634, .5R: 0.090909, .75R: 0.000000, count: 11, class_loss = 124.484154, iou_loss = 0.231552, total_loss = 124.715706
#  total_bbox = 51755, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.130325, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 276.840698, iou_loss = 0.000000, total_loss = 276.840698
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.245124, GIOU: -0.009800), Class: 0.534957, Obj: 0.293262, No Obj: 0.245499, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 235.654312, iou_loss = 0.062393, total_loss = 235.716705
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.321084, GIOU: 0.285085), Class: 0.559162, Obj: 0.386762, No Obj: 0.358017, .5R: 0.222222, .75R: 0.000000, count: 9, class_loss = 128.037949, iou_loss = 0.222992, total_loss = 128.260941
#  total_bbox = 51765, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.124506, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 252.754044, iou_loss = 0.000000, total_loss = 252.754044
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.176710, GIOU: 0.176710), Class: 0.495548, Obj: 0.268415, No Obj: 0.239698, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 226.908783, iou_loss = 0.043411, total_loss = 226.952194
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.275205, GIOU: 0.174045), Class: 0.597061, Obj: 0.397080, No Obj: 0.348857, .5R: 0.000000, .75R: 0.000000, count: 8, class_loss = 121.318359, iou_loss = 0.127159, total_loss = 121.445518
#  total_bbox = 51774, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.127077, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 262.477783, iou_loss = 0.000000, total_loss = 262.477783
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.214161, GIOU: 0.214162), Class: 0.665607, Obj: 0.479856, No Obj: 0.243990, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 233.039886, iou_loss = 0.064087, total_loss = 233.103973
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.379694, GIOU: 0.343113), Class: 0.523492, Obj: 0.379707, No Obj: 0.352788, .5R: 0.300000, .75R: 0.000000, count: 10, class_loss = 124.952301, iou_loss = 0.584465, total_loss = 125.536766
#  total_bbox = 51785, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.130636, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 279.930420, iou_loss = 0.000000, total_loss = 279.930420
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.167749, GIOU: 0.167749), Class: 0.488928, Obj: 0.271399, No Obj: 0.246748, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 239.395630, iou_loss = 0.081512, total_loss = 239.477142
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.304272, GIOU: 0.283230), Class: 0.513546, Obj: 0.341821, No Obj: 0.354932, .5R: 0.142857, .75R: 0.000000, count: 7, class_loss = 125.094994, iou_loss = 0.179306, total_loss = 125.274300
#  total_bbox = 51794, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.129337, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 273.700226, iou_loss = 0.000000, total_loss = 273.700226
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.244618, GIOU: 0.076654), Class: 0.461207, Obj: 0.242601, No Obj: 0.242087, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 231.747879, iou_loss = 0.123016, total_loss = 231.870895
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.434690, GIOU: 0.362712), Class: 0.501479, Obj: 0.395095, No Obj: 0.348557, .5R: 0.285714, .75R: 0.000000, count: 7, class_loss = 120.234680, iou_loss = 0.289734, total_loss = 120.524414
#  total_bbox = 51803, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.129454, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 274.240967, iou_loss = 0.000000, total_loss = 274.240967
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.427971, GIOU: 0.427971), Class: 0.520239, Obj: 0.338646, No Obj: 0.242953, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 231.384048, iou_loss = 0.817993, total_loss = 232.202042
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.336149, GIOU: 0.285954), Class: 0.523207, Obj: 0.416300, No Obj: 0.359450, .5R: 0.285714, .75R: 0.000000, count: 7, class_loss = 126.477646, iou_loss = 0.360947, total_loss = 126.838593
#  total_bbox = 51812, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.127310, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 264.159149, iou_loss = 0.000000, total_loss = 264.159149
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.221491, GIOU: 0.221491), Class: 0.534346, Obj: 0.316739, No Obj: 0.243068, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 232.652939, iou_loss = 0.140747, total_loss = 232.793686
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.330566, GIOU: 0.240443), Class: 0.538120, Obj: 0.346694, No Obj: 0.352716, .5R: 0.250000, .75R: 0.000000, count: 8, class_loss = 123.898727, iou_loss = 0.343391, total_loss = 124.242119
#  total_bbox = 51822, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.134840, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 296.297272, iou_loss = 0.000000, total_loss = 296.297272
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.501163, GIOU: 0.493242), Class: 0.500354, Obj: 0.252792, No Obj: 0.254749, .5R: 0.333333, .75R: 0.333333, count: 3, class_loss = 255.770523, iou_loss = 1.414200, total_loss = 257.184723
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.418580, GIOU: 0.373130), Class: 0.472602, Obj: 0.380724, No Obj: 0.357751, .5R: 0.200000, .75R: 0.100000, count: 10, class_loss = 128.614807, iou_loss = 0.581207, total_loss = 129.196014
#  total_bbox = 51835, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  107: 213.549103, 330.197815 avg loss, 0.000000 rate, 11.014349 seconds, 6848 images, 1.276349 hours left
# Loaded: 0.000047 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.124678, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 257.993073, iou_loss = 0.000000, total_loss = 257.993073
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.182454, GIOU: 0.182454), Class: 0.459875, Obj: 0.218576, No Obj: 0.236904, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 221.048126, iou_loss = 0.093735, total_loss = 221.141861
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.381023, GIOU: 0.347121), Class: 0.490733, Obj: 0.367141, No Obj: 0.348939, .5R: 0.272727, .75R: 0.000000, count: 11, class_loss = 124.397194, iou_loss = 0.429024, total_loss = 124.826218
#  total_bbox = 51848, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.125735, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 259.560455, iou_loss = 0.000000, total_loss = 259.560455
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.249470, GIOU: 0.249470), Class: 0.417226, Obj: 0.271604, No Obj: 0.239844, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 226.551025, iou_loss = 0.086792, total_loss = 226.637817
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.356013, GIOU: 0.311362), Class: 0.533436, Obj: 0.343381, No Obj: 0.349952, .5R: 0.000000, .75R: 0.000000, count: 8, class_loss = 121.748116, iou_loss = 0.283478, total_loss = 122.031593
#  total_bbox = 51857, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.124131, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 249.951614, iou_loss = 0.000000, total_loss = 249.951614
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.271517, GIOU: 0.108854), Class: 0.491888, Obj: 0.276033, No Obj: 0.234466, .5R: 0.000000, .75R: 0.000000, count: 7, class_loss = 221.078293, iou_loss = 0.855026, total_loss = 221.933319
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.286166, GIOU: 0.202367), Class: 0.541327, Obj: 0.428337, No Obj: 0.349135, .5R: 0.000000, .75R: 0.000000, count: 9, class_loss = 120.546089, iou_loss = 0.336235, total_loss = 120.882324
#  total_bbox = 51873, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.119139, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 232.572418, iou_loss = 0.000000, total_loss = 232.572418
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.261389, GIOU: 0.261389), Class: 0.526602, Obj: 0.168052, No Obj: 0.232686, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 216.823975, iou_loss = 0.206787, total_loss = 217.030762
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.281056, GIOU: 0.140540), Class: 0.424561, Obj: 0.375523, No Obj: 0.341052, .5R: 0.222222, .75R: 0.000000, count: 9, class_loss = 119.028801, iou_loss = 0.347565, total_loss = 119.376366
#  total_bbox = 51884, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.396443, GIOU: 0.339489), Class: 0.454730, Obj: 0.088121, No Obj: 0.123662, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 253.377243, iou_loss = 3.158981, total_loss = 256.536224
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.346720, GIOU: 0.341966), Class: 0.587908, Obj: 0.312881, No Obj: 0.235124, .5R: 0.333333, .75R: 0.000000, count: 3, class_loss = 220.140778, iou_loss = 1.757599, total_loss = 221.898376
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.284825, GIOU: 0.257868), Class: 0.509115, Obj: 0.424492, No Obj: 0.346363, .5R: 0.142857, .75R: 0.142857, count: 7, class_loss = 118.559105, iou_loss = 0.219208, total_loss = 118.778313
#  total_bbox = 51896, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.260790, GIOU: 0.028858), Class: 0.658421, Obj: 0.022869, No Obj: 0.124128, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 253.961624, iou_loss = 0.267944, total_loss = 254.229568
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.381434, GIOU: 0.154302), Class: 0.395879, Obj: 0.142525, No Obj: 0.235666, .5R: 0.333333, .75R: 0.000000, count: 3, class_loss = 223.296860, iou_loss = 2.601196, total_loss = 225.898056
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.296642, GIOU: 0.204507), Class: 0.537421, Obj: 0.378797, No Obj: 0.342871, .5R: 0.111111, .75R: 0.111111, count: 9, class_loss = 117.986763, iou_loss = 0.362114, total_loss = 118.348877
#  total_bbox = 51909, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.121243, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 243.363754, iou_loss = 0.000000, total_loss = 243.363754
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.164582, GIOU: 0.164582), Class: 0.560824, Obj: 0.196530, No Obj: 0.234959, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 218.906113, iou_loss = 0.037704, total_loss = 218.943817
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.387106, GIOU: 0.343302), Class: 0.562569, Obj: 0.344495, No Obj: 0.348400, .5R: 0.333333, .75R: 0.000000, count: 9, class_loss = 122.480568, iou_loss = 0.347397, total_loss = 122.827965
#  total_bbox = 51919, rewritten_bbox = 0.000000 %
# ...
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.296909, GIOU: 0.212495), Class: 0.599097, Obj: 0.162241, No Obj: 0.192891, .5R: 0.142857, .75R: 0.000000, count: 7, class_loss = 24.530146, iou_loss = 0.328848, total_loss = 24.858994
#  total_bbox = 59625, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.032836, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.045497, iou_loss = 0.000000, total_loss = 8.045497
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.293361, GIOU: 0.257191), Class: 0.615594, Obj: 0.093854, No Obj: 0.082345, .5R: 0.000000, .75R: 0.000000, count: 4, class_loss = 17.329227, iou_loss = 0.152430, total_loss = 17.481657
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.396997, GIOU: 0.230418), Class: 0.498858, Obj: 0.215488, No Obj: 0.187614, .5R: 0.500000, .75R: 0.000000, count: 8, class_loss = 23.847595, iou_loss = 0.203560, total_loss = 24.051155
#  total_bbox = 59637, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.034433, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.982150, iou_loss = 0.000000, total_loss = 8.982150
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.390310, GIOU: 0.340025), Class: 0.570013, Obj: 0.072605, No Obj: 0.086076, .5R: 0.200000, .75R: 0.000000, count: 5, class_loss = 19.905392, iou_loss = 0.474497, total_loss = 20.379889
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.442513, GIOU: 0.398560), Class: 0.530423, Obj: 0.185543, No Obj: 0.189950, .5R: 0.375000, .75R: 0.000000, count: 8, class_loss = 23.922588, iou_loss = 0.327971, total_loss = 24.250559
#  total_bbox = 59650, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033613, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.559226, iou_loss = 0.000000, total_loss = 8.559226
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.327483, GIOU: 0.275285), Class: 0.515370, Obj: 0.090941, No Obj: 0.082915, .5R: 0.125000, .75R: 0.000000, count: 8, class_loss = 22.760019, iou_loss = 0.759403, total_loss = 23.519423
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.391834, GIOU: 0.312945), Class: 0.542646, Obj: 0.193743, No Obj: 0.190475, .5R: 0.285714, .75R: 0.000000, count: 7, class_loss = 23.721098, iou_loss = 0.189247, total_loss = 23.910345
#  total_bbox = 59665, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033884, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.753181, iou_loss = 0.000000, total_loss = 8.753181
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.504724, GIOU: 0.488126), Class: 0.551888, Obj: 0.085352, No Obj: 0.082715, .5R: 0.400000, .75R: 0.000000, count: 5, class_loss = 18.174307, iou_loss = 1.683846, total_loss = 19.858152
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.439651, GIOU: 0.401874), Class: 0.555053, Obj: 0.151417, No Obj: 0.187005, .5R: 0.500000, .75R: 0.000000, count: 6, class_loss = 21.245445, iou_loss = 0.247746, total_loss = 21.493191
#  total_bbox = 59676, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.030982, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 7.589944, iou_loss = 0.000000, total_loss = 7.589944
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.082856, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 12.045409, iou_loss = 0.000000, total_loss = 12.045409
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.222171, GIOU: 0.112250), Class: 0.591905, Obj: 0.207635, No Obj: 0.189313, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 18.224979, iou_loss = 0.021923, total_loss = 18.246902
#  total_bbox = 59679, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033195, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.293937, iou_loss = 0.000000, total_loss = 8.293937
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.081527, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 11.622893, iou_loss = 0.000000, total_loss = 11.622893
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.330042, GIOU: 0.283438), Class: 0.526495, Obj: 0.267888, No Obj: 0.179674, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 16.083681, iou_loss = 0.042479, total_loss = 16.126160
#  total_bbox = 59682, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033462, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.279610, iou_loss = 0.000000, total_loss = 8.279610
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.084501, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 12.669335, iou_loss = 0.000000, total_loss = 12.669335
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.331223, GIOU: 0.327963), Class: 0.472339, Obj: 0.142743, No Obj: 0.183262, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 17.661245, iou_loss = 0.068758, total_loss = 17.730003
#  total_bbox = 59685, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.036708, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 9.832006, iou_loss = 0.000000, total_loss = 9.832006
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.088052, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 13.729026, iou_loss = 0.000000, total_loss = 13.729026
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.195339, GIOU: 0.195339), Class: 0.524462, Obj: 0.213607, No Obj: 0.185131, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 16.420019, iou_loss = 0.009008, total_loss = 16.429028
#  total_bbox = 59687, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033754, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.349545, iou_loss = 0.000000, total_loss = 8.349545
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.083670, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 12.410268, iou_loss = 0.000000, total_loss = 12.410268
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.303609, GIOU: 0.303609), Class: 0.530901, Obj: 0.160003, No Obj: 0.181908, .5R: 0.000000, .75R: 0.000000, count: 3, class_loss = 17.577560, iou_loss = 0.037930, total_loss = 17.615490
#  total_bbox = 59690, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033907, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.462357, iou_loss = 0.000000, total_loss = 8.462357
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.086359, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 13.187553, iou_loss = 0.000000, total_loss = 13.187553
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.418113, GIOU: 0.402877), Class: 0.512300, Obj: 0.178938, No Obj: 0.184328, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 16.538515, iou_loss = 0.011408, total_loss = 16.549923
#  total_bbox = 59692, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.035230, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 9.233321, iou_loss = 0.000000, total_loss = 9.233321
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.142977, GIOU: 0.142977), Class: 0.610268, Obj: 0.118485, No Obj: 0.086419, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 14.484524, iou_loss = 0.011920, total_loss = 14.496444
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.483405, GIOU: 0.435980), Class: 0.537996, Obj: 0.200693, No Obj: 0.188241, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 16.822283, iou_loss = 0.059853, total_loss = 16.882135
#  total_bbox = 59695, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033512, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.208363, iou_loss = 0.000000, total_loss = 8.208363
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.525723, GIOU: 0.504152), Class: 0.462932, Obj: 0.110468, No Obj: 0.084118, .5R: 0.500000, .75R: 0.500000, count: 2, class_loss = 15.245843, iou_loss = 0.408423, total_loss = 15.654266
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.486398, GIOU: 0.476699), Class: 0.454163, Obj: 0.220454, No Obj: 0.183355, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 16.306122, iou_loss = 0.147808, total_loss = 16.453930
#  total_bbox = 59699, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033253, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.247223, iou_loss = 0.000000, total_loss = 8.247223
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.085861, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 12.934721, iou_loss = 0.000000, total_loss = 12.934721
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.334429, GIOU: 0.334429), Class: 0.524051, Obj: 0.240434, No Obj: 0.188442, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 17.074938, iou_loss = 0.012253, total_loss = 17.087191
#  total_bbox = 59701, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.034591, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.809754, iou_loss = 0.000000, total_loss = 8.809754
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.085530, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 12.917144, iou_loss = 0.000000, total_loss = 12.917144
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.225582, GIOU: 0.225582), Class: 0.546904, Obj: 0.183185, No Obj: 0.187013, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 17.238316, iou_loss = 0.004629, total_loss = 17.242945
#  total_bbox = 59703, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.032605, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 7.885231, iou_loss = 0.000000, total_loss = 7.885231
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.273154, GIOU: 0.178242), Class: 0.620587, Obj: 0.051477, No Obj: 0.079824, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 12.675538, iou_loss = 0.011736, total_loss = 12.687274
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.242135, GIOU: 0.005113), Class: 0.506662, Obj: 0.289087, No Obj: 0.180607, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 15.880574, iou_loss = 0.015306, total_loss = 15.895880
#  total_bbox = 59706, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.035179, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 9.245190, iou_loss = 0.000000, total_loss = 9.245190
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.087613, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 13.518000, iou_loss = 0.000000, total_loss = 13.518000
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.337283, GIOU: 0.207084), Class: 0.619416, Obj: 0.147736, No Obj: 0.187991, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 16.891949, iou_loss = 0.009466, total_loss = 16.901415
#  total_bbox = 59708, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033706, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.398748, iou_loss = 0.000000, total_loss = 8.398748
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.085049, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 12.677627, iou_loss = 0.000000, total_loss = 12.677627
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.312462, GIOU: 0.312462), Class: 0.542158, Obj: 0.231638, No Obj: 0.192580, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 17.507751, iou_loss = 0.011208, total_loss = 17.518959
#  total_bbox = 59710, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033893, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.487286, iou_loss = 0.000000, total_loss = 8.487286
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.086734, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 13.259722, iou_loss = 0.000000, total_loss = 13.259722
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.205233, GIOU: 0.205233), Class: 0.534180, Obj: 0.350665, No Obj: 0.185388, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 16.280235, iou_loss = 0.004345, total_loss = 16.284580
#  total_bbox = 59712, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.033664, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 8.503238, iou_loss = 0.000000, total_loss = 8.503238
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.369970, GIOU: 0.287489), Class: 0.448561, Obj: 0.092577, No Obj: 0.083076, .5R: 0.333333, .75R: 0.000000, count: 3, class_loss = 15.758037, iou_loss = 0.292811, total_loss = 16.050848
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.617076, GIOU: 0.603707), Class: 0.828507, Obj: 0.137749, No Obj: 0.189543, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 16.282822, iou_loss = 0.189926, total_loss = 16.472748

# %% [markdown]
# **Resuming training from the last best weight file**

# %%
#!./darknet detector train cov_data/cov.data cov_yolov4.cfg /content/drive/'My Drive'/cov_weights/backup/cov_yolov4_best.weights

# %% [markdown]
# ## to use pretrained model

# %%
# !pip install --upgrade opencv-python==4.4.0.40
# Out:
# Collecting opencv-python==4.4.0.40
#   Downloading https://files.pythonhosted.org/packages/bd/8a/7a01233c28f4f0b49536498f2ae39aa9f70c6de85fe74dc17f53ec7d0b0e/opencv_python-4.4.0.40-cp36-cp36m-manylinux2014_x86_64.whl (49.4MB)
#      |████████████████████████████████| 49.4MB 86kB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==4.4.0.40) (1.19.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-4.4.0.40

# %% [markdown]
# ## test on images

# %% [markdown]
# ## import libraries

# %%
import numpy as  np
import cv2
from google.colab.patches import cv2_imshow
# load the image to detect, get width, height

# %%
def predict_mask(path):

  img_to_detect = cv2.imread(path)
  img_height = img_to_detect.shape[0]
  img_width = img_to_detect.shape[1]
  
  # convert to blob to pass into model
  img_blob = cv2.dnn.blobFromImage(img_to_detect, 0.003922, (416, 416), swapRB=True, crop=False)
  #recommended by yolo authors, scale factor is 0.003922=1/255, width,height of blob is 320,320
  #accepted sizes are 320×320,416×416,609×609. More size means more accuracy but less speed

  # set of 80 class labels 
  class_labels = ['with mask' ,'without mask']

  #Declare List of colors as an array
  #Green, Blue, Red, cyan, yellow, purple
  #Split based on ',' and for every split, change type to int
  #convert that to a numpy array to apply color mask to the image numpy array
  class_colors = ["0,255,0","255,255,0"]
  class_colors = [np.array(every_color.split(",")).astype("int") for every_color in class_colors]
  class_colors = np.array(class_colors)
  class_colors = np.tile(class_colors,(1,1))

  # Loading pretrained model 
  # input preprocessed blob into model and pass through the model
  # obtain the detection predictions by the model using forward() method
  yolo_model = cv2.dnn.readNetFromDarknet('/content/content/darknet/cov_yolov4.cfg','/content/gdrive/MyDrive/cov_weights/backup/cov_yolov4_last.weights')

  # Get all layers from the yolo network
  # Loop and find the last layer (output layer) of the yolo network 
  yolo_layers = yolo_model.getLayerNames()
  yolo_output_layer = [yolo_layers[yolo_layer[0] - 1] for yolo_layer in yolo_model.getUnconnectedOutLayers()]

  # input preprocessed blob into model and pass through the model
  yolo_model.setInput(img_blob)
  # obtain the detection layers by forwarding through till the output layer
  obj_detection_layers = yolo_model.forward(yolo_output_layer)


  ############## NMS Change 1 ###############
  # initialization for non-max suppression (NMS)
  # declare list for [class id], [box center, width & height[], [confidences]
  class_ids_list = []
  boxes_list = []
  confidences_list = []
  ############## NMS Change 1 END ###########


  # loop over each of the layer outputs
  for object_detection_layer in obj_detection_layers:
    # loop over the detections
      for object_detection in object_detection_layer:
          
          # obj_detections[1 to 4] => will have the two center points, box width and box height
          # obj_detections[5] => will have scores for all objects within bounding box
          all_scores = object_detection[5:]
          predicted_class_id = np.argmax(all_scores)
          prediction_confidence = all_scores[predicted_class_id]
      
          # take only predictions with confidence more than 20%
          if prediction_confidence > 0.20:
              #get the predicted label
              predicted_class_label = class_labels[predicted_class_id]
              #obtain the bounding box co-oridnates for actual image from resized image size
              bounding_box = object_detection[0:4] * np.array([img_width, img_height, img_width, img_height])
              (box_center_x_pt, box_center_y_pt, box_width, box_height) = bounding_box.astype("int")
              start_x_pt = int(box_center_x_pt - (box_width / 2))
              start_y_pt = int(box_center_y_pt - (box_height / 2))
              
              ############## NMS Change 2 ###############
              #save class id, start x, y, width & height, confidences in a list for nms processing
              #make sure to pass confidence as float and width and height as integers
              class_ids_list.append(predicted_class_id)
              confidences_list.append(float(prediction_confidence))
              boxes_list.append([start_x_pt, start_y_pt, int(box_width), int(box_height)])
              ############## NMS Change 2 END ###########
              
  ############## NMS Change 3 ###############
  # Applying the NMS will return only the selected max value ids while suppressing the non maximum (weak) overlapping bounding boxes      
  # Non-Maxima Suppression confidence set as 0.5 & max_suppression threhold for NMS as 0.4 (adjust and try for better perfomance)
  max_value_ids = cv2.dnn.NMSBoxes(boxes_list, confidences_list, 0.5, 0.4)

  # loop through the final set of detections remaining after NMS and draw bounding box and write text
  for max_valueid in max_value_ids:
      max_class_id = max_valueid[0]
      box = boxes_list[max_class_id]
      start_x_pt = box[0]
      start_y_pt = box[1]
      box_width = box[2]
      box_height = box[3]
      
      #get the predicted class id and label
      predicted_class_id = class_ids_list[max_class_id]
      predicted_class_label = class_labels[predicted_class_id]

      prediction_confidence = confidences_list[max_class_id]
  ############## NMS Change 3 END ########### 
            
      end_x_pt = start_x_pt + box_width
      end_y_pt = start_y_pt + box_height
      
      #get a random mask color from the numpy array of colors
      box_color = class_colors[predicted_class_id]
      
      #convert the color numpy array as a list and apply to text and box
      box_color = (255, 0, 0) 
      
      # print the prediction in console
      predicted_class_label = "{}: {:.2f}%".format(predicted_class_label, prediction_confidence * 100)
      print("predicted object {}".format(predicted_class_label))
      
      # draw rectangle and text in the image
      print(predicted_class_label)
      cv2.rectangle(img_to_detect, (start_x_pt, start_y_pt), (end_x_pt, end_y_pt),box_color, 1)
      cv2.putText(img_to_detect, predicted_class_label, (start_x_pt, start_y_pt-5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, box_color, 1)

  cv2_imshow(img_to_detect)

# %%
path = '/content/content/darknet/mask_detection/mask_images/105.jpg'

predict_mask(path)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-e7c8ea0eaa9c> in <module>()
#       1 path = '/content/content/darknet/mask_detection/mask_images/105.jpg'
#       2
# ----> 3 predict_mask(path)
#
# <ipython-input-2-b6e19067d955> in predict_mask(path)
#       9
#      10   # convert to blob to pass into model
# ---> 11   img_blob = cv2.dnn.blobFromImage(img_to_detect, 0.003922, (416, 416), swapRB=True, crop=False)
#      12   #recommended by yolo authors, scale factor is 0.003922=1/255, width,height of blob is 320,320
#      13   #accepted sizes are 320×320,416×416,609×609. More size means more accuracy but less speed
#
# error: OpenCV(4.4.0) /tmp/pip-req-build-_64nmdd7/opencv/modules/imgproc/src/resize.cpp:3929: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# ## test on video

# %%
def test_video(path):

    #get the webcam video stream
  file_video_stream = cv2.VideoCapture(path)

  #create a while loop 
  while (file_video_stream.isOpened):
      #get the current frame from video stream
      ret,current_frame = file_video_stream.read()
      #use the video current frame instead of image
      img_to_detect = current_frame

      img_height = img_to_detect.shape[0]
      img_width = img_to_detect.shape[1]
      
      # convert to blob to pass into model
      img_blob = cv2.dnn.blobFromImage(img_to_detect, 0.003922, (416, 416), swapRB=True, crop=False)
      #recommended by yolo authors, scale factor is 0.003922=1/255, width,height of blob is 320,320
      #accepted sizes are 320×320,416×416,609×609. More size means more accuracy but less speed
      
      # set of 80 class labels 
      class_labels = ["corona-virus"]
      
      #Declare List of colors as an array
      #Green, Blue, Red, cyan, yellow, purple
      #Split based on ',' and for every split, change type to int
      #convert that to a numpy array to apply color mask to the image numpy array
      class_colors = ["0,255,0"]
      class_colors = [np.array(every_color.split(",")).astype("int") for every_color in class_colors]
      class_colors = np.array(class_colors)
      class_colors = np.tile(class_colors,(1,1))
      
      # Loading pretrained model 
      # input preprocessed blob into model and pass through the model
      # obtain the detection predictions by the model using forward() method
      yolo_model = cv2.dnn.readNetFromDarknet('/content/gdrive/MyDrive/code/model/cov_yolov4.cfg','/content/gdrive/MyDrive/code/model/cov_yolov4_best.weights')
      
      # Get all layers from the yolo network
      # Loop and find the last layer (output layer) of the yolo network 
      yolo_layers = yolo_model.getLayerNames()
      yolo_output_layer = [yolo_layers[yolo_layer[0] - 1] for yolo_layer in yolo_model.getUnconnectedOutLayers()]
      
      # input preprocessed blob into model and pass through the model
      yolo_model.setInput(img_blob)
      # obtain the detection layers by forwarding through till the output layer
      obj_detection_layers = yolo_model.forward(yolo_output_layer)
      
      
      ############## NMS Change 1 ###############
      # initialization for non-max suppression (NMS)
      # declare list for [class id], [box center, width & height[], [confidences]
      class_ids_list = []
      boxes_list = []
      confidences_list = []
      ############## NMS Change 1 END ###########
      
      
      # loop over each of the layer outputs
      for object_detection_layer in obj_detection_layers:
        # loop over the detections
          for object_detection in object_detection_layer:
              
              # obj_detections[1 to 4] => will have the two center points, box width and box height
              # obj_detections[5] => will have scores for all objects within bounding box
              all_scores = object_detection[5:]
              predicted_class_id = np.argmax(all_scores)
              prediction_confidence = all_scores[predicted_class_id]
          
              # take only predictions with confidence more than 20%
              if prediction_confidence > 0.20:
                  #get the predicted label
                  predicted_class_label = class_labels[predicted_class_id]
                  #obtain the bounding box co-oridnates for actual image from resized image size
                  bounding_box = object_detection[0:4] * np.array([img_width, img_height, img_width, img_height])
                  (box_center_x_pt, box_center_y_pt, box_width, box_height) = bounding_box.astype("int")
                  start_x_pt = int(box_center_x_pt - (box_width / 2))
                  start_y_pt = int(box_center_y_pt - (box_height / 2))
                  
                  ############## NMS Change 2 ###############
                  #save class id, start x, y, width & height, confidences in a list for nms processing
                  #make sure to pass confidence as float and width and height as integers
                  class_ids_list.append(predicted_class_id)
                  confidences_list.append(float(prediction_confidence))
                  boxes_list.append([start_x_pt, start_y_pt, int(box_width), int(box_height)])
                  ############## NMS Change 2 END ###########
                  
      ############## NMS Change 3 ###############
      # Applying the NMS will return only the selected max value ids while suppressing the non maximum (weak) overlapping bounding boxes      
      # Non-Maxima Suppression confidence set as 0.5 & max_suppression threhold for NMS as 0.4 (adjust and try for better perfomance)
      max_value_ids = cv2.dnn.NMSBoxes(boxes_list, confidences_list, 0.5, 0.4)
      
      # loop through the final set of detections remaining after NMS and draw bounding box and write text
      for max_valueid in max_value_ids:
          max_class_id = max_valueid[0]
          box = boxes_list[max_class_id]
          start_x_pt = box[0]
          start_y_pt = box[1]
          box_width = box[2]
          box_height = box[3]
          
          #get the predicted class id and label
          predicted_class_id = class_ids_list[max_class_id]
          predicted_class_label = class_labels[predicted_class_id]
          prediction_confidence = confidences_list[max_class_id]
      ############## NMS Change 3 END ########### 
                
          end_x_pt = start_x_pt + box_width
          end_y_pt = start_y_pt + box_height
          
          #get a random mask color from the numpy array of colors
          box_color = class_colors[predicted_class_id]
          
          #convert the color numpy array as a list and apply to text and box
          box_color = [int(c) for c in box_color]
          
          # print the prediction in console
          predicted_class_label = "{}: {:.2f}%".format(predicted_class_label, prediction_confidence * 100)
          print("predicted object {}".format(predicted_class_label))
          
          # draw rectangle and text in the image
          cv2.rectangle(img_to_detect, (start_x_pt, start_y_pt), (end_x_pt, end_y_pt), box_color, 1)
          cv2.putText(img_to_detect, predicted_class_label, (start_x_pt, start_y_pt-5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, box_color, 1)
      
      cv2_imshow(img_to_detect)
      
      #terminate while loop if 'q' key is pressed
      if cv2.waitKey(1) & 0xFF == ord('q'):
          break

  #releasing the stream and the camera
  #close all opencv windows
  file_video_stream.release()
  cv2.destroyAllWindows()

# %%
path = '/content/content/darknet/mask_detection/mask_images/104.jpg'

test_video(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-619919082ab9> in <module>()
#       1 path = '/content/content/darknet/mask_detection/mask_images/104.jpg'
#       2
# ----> 3 test_video(path)
#
# NameError: name 'test_video' is not defined
